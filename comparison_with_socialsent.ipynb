# %%
import sys

import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from collections import defaultdict
import pandas as pd

# Matplotlib for additional customization
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Using left-/right-est word vectors to define axis

# %%
df = pd.read_table('./polarities_comparison_google.txt')
g = sns.lmplot(x="socialsent", y="ourmethod", data=df)

# %% [markdown]
# ## Using average vector to define axis

# %%
df = pd.read_table('./polarities_comparison_byaveraging_google.txt')
g = sns.lmplot(x="socialsent", y="ourmethod", data=df)

# %%
df = pd.read_table('./polarities_comparison_google.txt')
g = sns.lmplot(x="socialsent", y="ourmethod", data=df)
g.savefig('plot/sentprop_vs_ourmethod_googlenews-w2v_general-inquirer-lexicon.jpg')
